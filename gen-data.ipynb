# %% [markdown]
# ## Nation

# %% [markdown]
# **TODO**:
#   1. Add an `end_year` parameter, and make all functions use it, so this is easier to update when new data comes in.
#   2. Add places and MSAs
#   3. Convert this into a script that can be run with a single command.

# %%
from acs_nativity import get_nativity_timeseries

# %%
df_us = get_nativity_timeseries(us="*")
df_us
# Out:
# ...................
#              Name  Year      Total     Native  Foreign-born  \
# 0   United States  2005  288378137  252688295      35689842
# 1   United States  2006  299398485  261850696      37547789
# 2   United States  2007  301621159  263561465      38059694
# 3   United States  2008  304059728  266098793      37960935
# 4   United States  2009  307006556  268489322      38517234
# 5   United States  2010  309349689  269393835      39955854
# 6   United States  2011  311591919  271214059      40377860
# 7   United States  2012  313914040  273089382      40824658
# 8   United States  2013  316128839  274780773      41348066
# 9   United States  2014  318857056  276465262      42391794
# 10  United States  2015  321418821  278128449      43290372
# 11  United States  2016  323127515  279388170      43739345
# 12  United States  2017  325719178  281193323      44525855
# 13  United States  2018  327167439  282438718      44728721
# 14  United States  2019  328239523  283306622      44932901
# 15  United States  2021  331893745  286623642      45270103
# 16  United States  2022  333287562  287105385      46182177
# 17  United States  2023  334914896  287083485      47831411
# 18  United States  2024  340110990  289876132      50234858
#
#     Percent Foreign-born
# 0              12.376057
# 1              12.541075
# 2              12.618377
# 3              12.484697
# 4              12.546062
# 5              12.916080
# 6              12.958571
# 7              13.005044
# 8              13.079498
# 9              13.294921
# 10             13.468524
# 11             13.536249
# 12             13.670013
# 13             13.671508
# 14             13.689059
# 15             13.639939
# 16             13.856556
# 17             14.281661
# 18             14.770137

# %%
df_us.to_csv("us.csv", index=False)

# %% [markdown]
# ## State

# %%
df_state = get_nativity_timeseries(state="*")
df_state
# Out:
# ...................
#               Name  Year       Total      Native  Foreign-born  \
# 0          Alabama  2005   4442558.0   4321785.0      120773.0
# 1           Alaska  2005    641724.0    607356.0       34368.0
# 2          Arizona  2005   5829839.0   4986543.0      843296.0
# 3         Arkansas  2005   2701431.0   2600262.0      101169.0
# 4       California  2005  35278768.0  25667412.0     9611356.0
# ..             ...   ...         ...         ...           ...
# 983     Washington  2024   7958180.0   6677371.0     1280809.0
# 984  West Virginia  2024   1769979.0   1732726.0       37253.0
# 985      Wisconsin  2024   5960975.0   5633942.0      327033.0
# 986        Wyoming  2024    587618.0    567162.0       20456.0
# 987    Puerto Rico  2024         NaN         NaN           NaN
#
#      Percent Foreign-born
# 0                2.718546
# 1                5.355573
# 2               14.465168
# 3                3.745015
# 4               27.244024
# ..                    ...
# 983             16.094245
# 984              2.104714
# 985              5.486233
# 986              3.481173
# 987                   NaN
#
# [988 rows x 6 columns]

# %%
df_state = df_state[df_state["Name"] != "Puerto Rico"]
df_state
# Out:
#               Name  Year       Total      Native  Foreign-born  \
# 0          Alabama  2005   4442558.0   4321785.0      120773.0
# 1           Alaska  2005    641724.0    607356.0       34368.0
# 2          Arizona  2005   5829839.0   4986543.0      843296.0
# 3         Arkansas  2005   2701431.0   2600262.0      101169.0
# 4       California  2005  35278768.0  25667412.0     9611356.0
# ..             ...   ...         ...         ...           ...
# 982       Virginia  2024   8811195.0   7617614.0     1193581.0
# 983     Washington  2024   7958180.0   6677371.0     1280809.0
# 984  West Virginia  2024   1769979.0   1732726.0       37253.0
# 985      Wisconsin  2024   5960975.0   5633942.0      327033.0
# 986        Wyoming  2024    587618.0    567162.0       20456.0
#
#      Percent Foreign-born
# 0                2.718546
# 1                5.355573
# 2               14.465168
# 3                3.745015
# 4               27.244024
# ..                    ...
# 982             13.546188
# 983             16.094245
# 984              2.104714
# 985              5.486233
# 986              3.481173
#
# [969 rows x 6 columns]

# %%
df_state["Name"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df_state.to_csv("state.csv", index=False)

# %% [markdown]
# ## County

# %%
from censusdis import states
import pandas as pd

dfs = []
for state in states.ALL_STATES_AND_DC:
    print(f"Getting data for {states.NAMES_FROM_IDS[state]}")
    df_new = get_nativity_timeseries(state=state, county="*")
    print(f"Num rows is {len(df_new)}")
    dfs.append(df_new)

df_county = pd.concat(dfs)
df_county.to_csv("county.csv", index=False)
df_county
# Out:
# Getting data for Alabama
# ...................Num rows is 396
# Getting data for Alaska
# ...................Num rows is 57
# Getting data for Arizona
# ...................Num rows is 190
# Getting data for Arkansas
# ...................Num rows is 206
# Getting data for California
# ...................Num rows is 769
# Getting data for Colorado
# ...................Num rows is 218
# Getting data for Connecticut
# ...................Num rows is 155
# Getting data for District of Columbia
# ...................Num rows is 19
# Getting data for Delaware
# ...................Num rows is 57
# Getting data for Florida
# ...................Num rows is 765
# Getting data for Georgia
# ...................Num rows is 672
# Getting data for Hawaii
# ...................Num rows is 71
# Getting data for Idaho
# ...................Num rows is 114
# Getting data for Illinois
# ...................Num rows is 429
# Getting data for Indiana
# ...................Num rows is 484
# Getting data for Iowa
# ...................Num rows is 185
# Getting data for Kansas
# ...................Num rows is 145
# Getting data for Kentucky
# ...................Num rows is 248
# Getting data for Louisiana
# ...................Num rows is 324
# Getting data for Maine
# ...................Num rows is 114
# Getting data for Maryland
# ...................Num rows is 304
# Getting data for Massachusetts
# ...................Num rows is 228
# Getting data for Minnesota
# ...................Num rows is 260
# Getting data for Mississippi
# ...................Num rows is 194
# Getting data for Michigan
# ...................Num rows is 554
# Getting data for Missouri
# ...................Num rows is 319
# Getting data for Montana
# ...................Num rows is 106
# Getting data for Nebraska
# ...................Num rows is 57
# Getting data for Nevada
# ...................Num rows is 38
# Getting data for New Hampshire
# ...................Num rows is 116
# Getting data for New Jersey
# ...................Num rows is 399
# Getting data for New Mexico
# ...................Num rows is 169
# Getting data for New York
# ...................Num rows is 732
# Getting data for North Carolina
# ...................Num rows is 756
# Getting data for North Dakota
# ...................Num rows is 68
# Getting data for Ohio
# ...................Num rows is 726
# Getting data for Oklahoma
# ...................Num rows is 208
# Getting data for Oregon
# ...................Num rows is 285
# Getting data for Pennsylvania
# ...................Num rows is 752
# Getting data for Rhode Island
# ...................Num rows is 76
# Getting data for South Carolina
# ...................Num rows is 402
# Getting data for South Dakota
# ...................Num rows is 42
# Getting data for Tennessee
# ...................Num rows is 380
# Getting data for Texas
# ...................Num rows is 1004
# Getting data for Utah
# ...................Num rows is 122
# Getting data for Vermont
# ...................Num rows is 19
# Getting data for Virginia
# ...................Num rows is 559
# Getting data for Washington
# ...................Num rows is 366
# Getting data for West Virginia
# ...................Num rows is 133
# Getting data for Wisconsin
# ...................Num rows is 445
# Getting data for Wyoming
# ...................Num rows is 38
#                        Name  Year     Total    Native  Foreign-born  \
# 0   Baldwin County, Alabama  2005  160354.0  155982.0        4372.0
# 1   Calhoun County, Alabama  2005  109762.0  107543.0        2219.0
# 2   Cullman County, Alabama  2005   78888.0   77073.0        1815.0
# 3    DeKalb County, Alabama  2005   66407.0   63325.0        3082.0
# 4    Elmore County, Alabama  2005   68057.0   67262.0         795.0
# ..                      ...   ...       ...       ...           ...
# 33  Natrona County, Wyoming  2022   79601.0   77875.0        1726.0
# 34  Laramie County, Wyoming  2023  100984.0   97853.0        3131.0
# 35  Natrona County, Wyoming  2023   79941.0   77282.0        2659.0
# 36  Laramie County, Wyoming  2024  101783.0   98734.0        3049.0
# 37  Natrona County, Wyoming  2024   80410.0   78793.0        1617.0
#
#     Percent Foreign-born
# 0               2.726468
# 1               2.021647
# 2               2.300730
# 3               4.641077
# 4               1.168138
# ..                   ...
# 33              2.168314
# 34              3.100491
# 35              3.326203
# 36              2.995589
# 37              2.010944
#
# [15475 rows x 6 columns]

# %%
# Assert all names have exactly 1 comma. i.e. "county, state"
num_commas = df_county["Name"].str.count(",")
(num_commas == 1).all()
# Out:
# False

# %%
df_county
# Out:
#                        Name  Year     Total    Native  Foreign-born  \
# 0   Baldwin County, Alabama  2005  160354.0  155982.0        4372.0
# 1   Calhoun County, Alabama  2005  109762.0  107543.0        2219.0
# 2   Cullman County, Alabama  2005   78888.0   77073.0        1815.0
# 3    DeKalb County, Alabama  2005   66407.0   63325.0        3082.0
# 4    Elmore County, Alabama  2005   68057.0   67262.0         795.0
# ..                      ...   ...       ...       ...           ...
# 33  Natrona County, Wyoming  2022   79601.0   77875.0        1726.0
# 34  Laramie County, Wyoming  2023  100984.0   97853.0        3131.0
# 35  Natrona County, Wyoming  2023   79941.0   77282.0        2659.0
# 36  Laramie County, Wyoming  2024  101783.0   98734.0        3049.0
# 37  Natrona County, Wyoming  2024   80410.0   78793.0        1617.0
#
#     Percent Foreign-born
# 0               2.726468
# 1               2.021647
# 2               2.300730
# 3               4.641077
# 4               1.168138
# ..                   ...
# 33              2.168314
# 34              3.100491
# 35              3.326203
# 36              2.995589
# 37              2.010944
#
# [15475 rows x 6 columns]

# %%
df_county[["County", "State"]] = df_county["Name"].str.split(",", expand=True)
df_county["County"] = df_county["County"].str.strip()
df_county["State"] = df_county["State"].str.strip()
df_county = df_county[
    [
        "State",
        "County",
        "Name",
        "Year",
        "Total",
        "Native",
        "Foreign-born",
        "Percent Foreign-born",
    ]
]

df_county
# Out:
#       State          County                     Name  Year     Total  \
# 0   Alabama  Baldwin County  Baldwin County, Alabama  2005  160354.0
# 1   Alabama  Calhoun County  Calhoun County, Alabama  2005  109762.0
# 2   Alabama  Cullman County  Cullman County, Alabama  2005   78888.0
# 3   Alabama   DeKalb County   DeKalb County, Alabama  2005   66407.0
# 4   Alabama   Elmore County   Elmore County, Alabama  2005   68057.0
# ..      ...             ...                      ...   ...       ...
# 33  Wyoming  Natrona County  Natrona County, Wyoming  2022   79601.0
# 34  Wyoming  Laramie County  Laramie County, Wyoming  2023  100984.0
# 35  Wyoming  Natrona County  Natrona County, Wyoming  2023   79941.0
# 36  Wyoming  Laramie County  Laramie County, Wyoming  2024  101783.0
# 37  Wyoming  Natrona County  Natrona County, Wyoming  2024   80410.0
#
#       Native  Foreign-born  Percent Foreign-born
# 0   155982.0        4372.0              2.726468
# 1   107543.0        2219.0              2.021647
# 2    77073.0        1815.0              2.300730
# 3    63325.0        3082.0              4.641077
# 4    67262.0         795.0              1.168138
# ..       ...           ...                   ...
# 33   77875.0        1726.0              2.168314
# 34   97853.0        3131.0              3.100491
# 35   77282.0        2659.0              3.326203
# 36   98734.0        3049.0              2.995589
# 37   78793.0        1617.0              2.010944
#
# [15475 rows x 8 columns]

# %%
df_county.to_csv("county.csv", index=False)

# %% [markdown]
# ## Places

# %% [markdown]
# ## MSAs
